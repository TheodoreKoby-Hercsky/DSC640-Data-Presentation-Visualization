# %%
# First I will import some needed libraries
import pandas as pd
from importlib import reload
import sys
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.gridspec as gridspec 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Importing the Data

# %%
# I will use pandas to pull the data to create a data frame for birth-rate
birth_rate = pd.read_csv('birth-rate.csv')
birth_rate
# Out:
#                   Country    1960    1961    1962    1963    1964    1965  \
# 0                   Aruba  36.400  35.179  33.863  32.459  30.994  29.513
# 1             Afghanistan  52.201  52.206  52.208  52.204  52.192  52.168
# 2                  Angola  54.432  54.394  54.317  54.199  54.040  53.836
# 3                 Albania  40.886  40.312  39.604  38.792  37.913  37.008
# 4    Netherlands Antilles  32.321  30.987  29.618  28.229  26.849  25.518
# ..                    ...     ...     ...     ...     ...     ...     ...
# 229                 Samoa  48.202  47.788  47.226  46.491  45.591  44.558
# 230           Yemen, Rep.  54.501  54.516  54.563  54.645  54.761  54.914
# 231          South Africa  42.267  41.993  41.610  41.112  40.520  39.883
# 232                Zambia  48.112  48.323  48.533  48.734  48.915  49.061
# 233              Zimbabwe  48.178  48.179  48.148  48.079  47.977  47.852
#
#        1966    1967    1968  ...    1999    2000    2001    2002    2003  \
# ...

# %%
# I will use pandas to pull the data to create a data frame for birth_rate_yearly
birth_rate_yearly = pd.read_csv('birth-rates-yearly.csv')
birth_rate_yearly
# Out:
#       year    rate
# 0     1960  36.400
# 1     1961  35.179
# 2     1962  33.863
# 3     1963  32.459
# 4     1964  30.994
# ...    ...     ...
# 9865  2004  30.123
# 9866  2005  30.067
# 9867  2006  30.027
# 9868  2007  29.987
# 9869  2008  29.930
#
# [9870 rows x 2 columns]

# %%
# I will use pandas to pull the data to create a data frame for crimerates_by_state_2005
crimerates_by_state_2005 = pd.read_csv('crimerates-by-state-2005.csv')
crimerates_by_state_2005
# Out:
#                    state  murder  forcible_rape  robbery  aggravated_assault  \
# 0          United States     5.6           31.7    140.7               291.1
# 1                Alabama     8.2           34.3    141.4               247.8
# 2                 Alaska     4.8           81.1     80.9               465.1
# 3                Arizona     7.5           33.8    144.4               327.4
# 4               Arkansas     6.7           42.9     91.1               386.8
# 5             California     6.9           26.0    176.1               317.3
# 6               Colorado     3.7           43.4     84.6               264.7
# 7            Connecticut     2.9           20.0    113.0               138.6
# 8               Delaware     4.4           44.7    154.8               428.2
# 9   District of Columbia    35.4           30.2    672.1               721.3
# 10               Florida     5.0           37.1    169.4               496.6
# ...

# %%
# I will use pandas to pull the data to create a data frame for life-expectancy
life_expectancy = pd.read_csv('life-expectancy.csv')
life_expectancy
# Out:
#                                 country  year  expectancy
# 0                           Afghanistan  2008          42
# 1                               Albania  2008          73
# 2                               Algeria  2008          71
# 3                                Angola  2008          46
# 4                   Antigua and Barbuda  2008          74
# ..                                  ...   ...         ...
# 182  Venezuela (Bolivarian Republic of)  2008          75
# 183                            Viet Nam  2008          73
# 184                               Yemen  2008          64
# 185                              Zambia  2008          48
# 186                            Zimbabwe  2008          42
#
# [187 rows x 3 columns]

# %%
# Next I will use info to see further information on each of my variables.
crimerates_by_state_2005.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                52 non-null     object
#  1   murder               52 non-null     float64
#  2   forcible_rape        52 non-null     float64
#  3   robbery              52 non-null     float64
#  4   aggravated_assault   52 non-null     float64
#  5   burglary             52 non-null     float64
#  6   larceny_theft        52 non-null     float64
#  7   motor_vehicle_theft  52 non-null     float64
#  8   population           52 non-null     int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 3.8+ KB

# %%
crimerates_by_state_2005['population'].nlargest(n=10)
# Out:
# 0     295753151
# 5      35795255
# 44     22801920
# 33     19330891
# 10     17783868
# 14     12674452
# 39     12418161
# 36     11475262
# 23     10090554
# 11      9097428
# Name: population, dtype: int64

# %%
crimerates_by_state_2005.drop(crimerates_by_state_2005[crimerates_by_state_2005['population'] >= 10090554].index, inplace = True)

# %%
crimerates_by_state_2005['population'].nlargest(n=10)
# Out:
# 11    9097428
# 34    8669452
# 31    8621837
# 47    7563887
# 22    6453031
# 48    6261282
# 15    6253120
# 43    5995748
# 3     5974834
# 26    5806639
# Name: population, dtype: int64

# %%
# Create a scatterplot that displays different crimes by 
# population in hunder thousands
population = crimerates_by_state_2005.population
aggravated_assault = crimerates_by_state_2005.aggravated_assault
burglary = crimerates_by_state_2005.burglary
larceny_theft = crimerates_by_state_2005.larceny_theft
plt.scatter(population,aggravated_assault,color='red', marker= '.', 
            label='Aggravated Assault')
plt.scatter(population,burglary,color= 'blue', marker='v', 
            label='Burglary')
plt.scatter(population,larceny_theft,color= 'green', marker='*', 
            label='Larceny Theft')
plt.title('Crime by Population')
plt.xlabel('Population')
plt.ylabel('Crime')
plt.legend(loc='best')
plt.show()

# %%
birth_rate_yearly['year'].nlargest(n=10)
# Out:
# 48     2008
# 97     2008
# 146    2008
# 195    2008
# 244    2008
# 277    2008
# 326    2008
# 375    2008
# 424    2008
# 498    2008
# Name: year, dtype: int64

# %%
# Create a bubble plot by using matplotlib.pyplot 
# and numpyfor population and crime
population = crimerates_by_state_2005.population
murder = crimerates_by_state_2005.murder
forcible_rape = crimerates_by_state_2005.forcible_rape
plt.scatter(population, murder, s=forcible_rape*100, alpha=0.5)
plt.title('Crime by Population')
plt.xlabel('Population')
plt.ylabel('Crime')
plt.show()

# %%
# Create a density plot through the use of seaborn kdeplot
plt.figure(figsize = (5,5))
sns.kdeplot(life_expectancy.expectancy, fill = True, color='red')
plt.title('Life Expectancy')
plt.xlabel('Age')
plt.show()
